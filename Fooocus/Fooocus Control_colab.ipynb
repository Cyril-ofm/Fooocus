# %% [markdown]
# <a href="https://colab.research.google.com/github/Cyril-ofm/Fooocus/blob/main/Fooocus/Fooocus%20Control_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install Fooocus
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --preset realistic --share
# Out:
# ...
# /content
# fatal: destination path 'Fooocus' already exists and is not an empty directory.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--preset', 'realistic', '--share']
# Loaded preset: /content/Fooocus/presets/realistic.json
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.864
# Version mismatch for gradio: Installed version 3.39.0 does not meet requirement gradio==3.41.2
# Installing requirements
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v20.safetensors" to /content/Fooocus/models/checkpoints/realisticStockPhoto_v20.safetensors
#
# 100% 6.46G/6.46G [00:32<00:00, 212MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors" to /content/Fooocus/models/loras/SDXL_FILM_PHOTOGRAPHY_STYLE_BetaV0.4.safetensors
#
# 100% 222M/222M [00:01<00:00, 228MB/s]
# ...

# %%
# Install Fooocus Control
# !pip install pygit2==1.12.2
# %cd /content
# !git clone https://github.com/fenneishi/Fooocus-Control.git
# %cd /content/Fooocus-Control
# !cp colab_fix.txt user_path_config.txt
# !python entry_with_update.py --share



# Install required libraries for web api
#!pip -q install fastapi
# !pip -q install pyngrok
# !pip -q install uvicorn
# !pip -q install nest_asyncio
# !pip -q install python-multipart
# !pip uninstall fastapi typing-extensions -y
# !pip install fastapi typing-extensions==4.8.0 --no-cache-dir


# Import libraries
import uvicorn
from typing_extensions import Annotated#, Doc
from fastapi import FastAPI
from fastapi.middleware.cors import CORSMiddleware
from pyngrok import ngrok
from pydantic import BaseModel
import nest_asyncio
import shutil

# Import models for serialisation/ deserialisation
from pydantic import BaseModel
import base64
import io
import wave

nest_asyncio.apply()

app = FastAPI()

app.add_middleware(
    CORSMiddleware,
    allow_origins=['*'],
    allow_credentials=True,
    allow_methods=['*'],
    allow_headers=['*'],
)
# Out:
# ...
# /content
# fatal: destination path 'Fooocus-Control' already exists and is not an empty directory.
# /content/Fooocus-Control
# Already up-to-date
# Update succeeded.
# Python 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
# Fooocus version: 2.1.701
# Installing requirements
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0_0.9vae.safetensors" to /content/Fooocus-Control/models/checkpoints/sd_xl_base_1.0_0.9vae.safetensors
#
# 100% 6.46G/6.46G [00:24<00:00, 279MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-refiner-1.0/resolve/main/sd_xl_refiner_1.0_0.9vae.safetensors" to /content/Fooocus-Control/models/checkpoints/sd_xl_refiner_1.0_0.9vae.safetensors
#
# 100% 5.66G/5.66G [00:20<00:00, 297MB/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Install models for Fooocus Comtrol
# !wget -O /content/Fooocus-Control/models/checkpoints/realisticVisionV51_v51VAE.safetensors https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticVisionV51_v51VAE.safetensors?download=true
# !wget -O /content/Fooocus-Control/models/inpaint/control_v11p_sd15_inpaint.safetensors https://huggingface.co/lllyasviel/control_v11p_sd15_inpaint/tree/main
# !wget -O /content/Fooocus-Control/models/loras/sd_xl_offset_example-lora_1.0.safetensors https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors?download=true
# !wget -O /content/Fooocus-Control/models/checkpoints/sd_xl_base_1.0_0.9vae.safetensors https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0_0.9vae.safetensors?download=true
# !wget -O /content/Fooocus-Control/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors
# !wget -O /content/Fooocus-Control/models/checkpoints/jibMixRealisticXL_v70PromptAdherence.safetensors https://huggingface.co/Thekingbalxd/fav_models/resolve/main/jibMixRealisticXL_v70PromptAdherence.safetensors?download=true
# Out:
# --2024-01-29 13:26:13--  https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticVisionV51_v51VAE.safetensors?download=true
# Resolving huggingface.co (huggingface.co)... 18.155.68.4, 18.155.68.99, 18.155.68.111, ...
# Connecting to huggingface.co (huggingface.co)|18.155.68.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# Install models for Fooocus
# !wget -O /content/Fooocus/models/checkpoints/realisticVisionV51_v51VAE.safetensors https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticVisionV51_v51VAE.safetensors?download=true
# !wget -O /content/Fooocus/models/inpaint/control_v11p_sd15_inpaint.safetensors https://huggingface.co/lllyasviel/control_v11p_sd15_inpaint/tree/main
# !wget -O /content/Fooocus/models/checkpoints/sd_xl_base_1.0_0.9vae.safetensors https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0_0.9vae.safetensors?download=true
# !wget -O /content/Fooocus/models/checkpoints/sd_xl_base_1.0.safetensors https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_base_1.0.safetensors?download=true
# !wget -O /content/Fooocus/models/checkpoints/jibMixRealisticXL_v70PromptAdherence.safetensors https://huggingface.co/Thekingbalxd/fav_models/resolve/main/jibMixRealisticXL_v70PromptAdherence.safetensors?download=true
# Out:
# --2024-01-29 13:19:26--  https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticVisionV51_v51VAE.safetensors?download=true
# Resolving huggingface.co (huggingface.co)... 18.155.68.4, 18.155.68.124, 18.155.68.111, ...
# Connecting to huggingface.co (huggingface.co)|18.155.68.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
